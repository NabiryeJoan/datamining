# %%
import pandas as pd
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8656\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\agroget_away_backend\datamining\BI_PRAC.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/agroget_away_backend/datamining/BI_PRAC.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/d%3A/agroget_away_backend/datamining/BI_PRAC.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import numpy as np
#       <a href='vscode-notebook-cell:/d%3A/agroget_away_backend/datamining/BI_PRAC.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# i have imported the libraries

# %%
kent = pd.read_csv('/content/apple.csv')

# %% [markdown]
# to import the dataset

# %%
kent.head()
# Out:
#          date       high        low       open      close       volume  \
# 0  2019-01-02  39.712502  38.557499  38.722500  39.480000  148158800.0
# 1  2019-01-03  36.430000  35.500000  35.994999  35.547501  365248800.0
# 2  2019-01-04  37.137501  35.950001  36.132500  37.064999  234428400.0
# 3  2019-01-07  37.207500  36.474998  37.174999  36.982498  219111200.0
# 4  2019-01-08  37.955002  37.130001  37.389999  37.687500  164101200.0
#
#    adj_close
# 0  38.562561
# 1  34.721451
# 2  36.203678
# 3  36.123104
# 4  36.811718

# %% [markdown]
# reading the dataset

# %%
kent.head(20)
# Out:
#           date       high        low       open      close       volume  \
# 0   2019-01-02  39.712502  38.557499  38.722500  39.480000  148158800.0
# 1   2019-01-03  36.430000  35.500000  35.994999  35.547501  365248800.0
# 2   2019-01-04  37.137501  35.950001  36.132500  37.064999  234428400.0
# 3   2019-01-07  37.207500  36.474998  37.174999  36.982498  219111200.0
# 4   2019-01-08  37.955002  37.130001  37.389999  37.687500  164101200.0
# 5   2019-01-09  38.632500  37.407501  37.822498  38.327499  180396400.0
# 6   2019-01-10  38.492500  37.715000  38.125000  38.450001  143122800.0
# 7   2019-01-11  38.424999  37.877499  38.220001  38.072498  108092800.0
# 8   2019-01-14  37.817501  37.305000  37.712502  37.500000  129756800.0
# 9   2019-01-15  38.347500  37.512501  37.567501  38.267502  114843600.0
# 10  2019-01-16  38.970001  38.250000  38.270000  38.735001  122278800.0
# 11  2019-01-17  39.415001  38.314999  38.549999  38.965000  119284800.0
# ...

# %% [markdown]
# reading only  the first 20
#
# ```
# # This is formatted as code
# ```

# %%
kent.tail()
# Out:
#            date        high         low        open       close       volume  \
# 500  2020-12-24  133.460007  131.100006  131.320007  131.970001   54930100.0
# 501  2020-12-28  137.339996  133.509995  133.990005  136.690002  124182900.0
# 502  2020-12-29  138.789993  134.339996  138.050003  134.869995  121047300.0
# 503  2020-12-30  135.990005  133.399994  135.580002  133.720001   96452100.0
# 504  2020-12-31  134.740005  131.720001  134.080002  132.690002   98990400.0
#
#       adj_close
# 500  131.970001
# 501  136.690002
# 502  134.869995
# 503  133.720001
# 504  132.690002

# %% [markdown]
# reading the last 5

# %%
kent.shape
# Out:
# (505, 7)

# %% [markdown]
# how many columns and rows our dataset has

# %%
kent.dtypes
# Out:
# date          object
# high         float64
# low          float64
# open         float64
# close        float64
# volume       float64
# adj_close    float64
# dtype: object

# %% [markdown]
# what are the data types in column

# %%
kent.describe()
# Out:
#              high         low        open       close        volume  \
# count  505.000000  505.000000  505.000000  505.000000  5.050000e+02
# mean    74.603614   72.782277   73.660342   73.748386  1.348890e+08
# std     27.759058   26.807426   27.362346   27.280933  6.236881e+07
# min     36.430000   35.500000   35.994999   35.547501  4.544800e+07
# 25%     51.235001   50.407501   50.790001   50.782501  9.252240e+07
# 50%     67.500000   65.862503   66.650002   66.730003  1.186556e+08
# 75%     92.970001   90.910004   91.279999   91.632500  1.581300e+08
# max    138.789993  134.339996  138.050003  136.690002  4.268848e+08
#
#         adj_close
# count  505.000000
# mean    73.220703
# std     27.531233
# min     34.721451
# 25%     50.031612
# 50%     66.158653
# 75%     91.310051
# max    136.690002

# %% [markdown]
# summary statisitcial analysis of our data

# %%
kent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       505 non-null    object
#  1   high       505 non-null    float64
#  2   low        505 non-null    float64
#  3   open       505 non-null    float64
#  4   close      505 non-null    float64
#  5   volume     505 non-null    float64
#  6   adj_close  505 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 27.7+ KB

# %% [markdown]
# no null there is no missing value...it helps us to confirm that we dont have missing value.

# %%
kent.isnull().sum()
# Out:
# date         0
# high         0
# low          0
# open         0
# close        0
# volume       0
# adj_close    0
# dtype: int64

# %% [markdown]
# it counts the null values.

# %%
kent.isnull()
# Out:
#       date   high    low   open  close  volume  adj_close
# 0    False  False  False  False  False   False      False
# 1    False  False  False  False  False   False      False
# 2    False  False  False  False  False   False      False
# 3    False  False  False  False  False   False      False
# 4    False  False  False  False  False   False      False
# ..     ...    ...    ...    ...    ...     ...        ...
# 500  False  False  False  False  False   False      False
# 501  False  False  False  False  False   False      False
# 502  False  False  False  False  False   False      False
# 503  False  False  False  False  False   False      False
# 504  False  False  False  False  False   False      False
#
# [505 rows x 7 columns]

# %% [markdown]
# proving if we have a missing value

# %%
joan = pd.read_excel('SalesTransactions.xlsx')

# %%
joan.shape
# Out:
# (474, 8)

# %%
joan = pd.read_excel('/content/SalesTransactions.xlsx')

# %%
joan.head
# Out:
# <bound method NDFrame.head of     Sales Transactions: July 14 Unnamed: 1 Unnamed: 2        Unnamed: 3  \
# 0                           NaN        NaN        NaN               NaN
# 1                       Cust ID     Region   Payment   Transaction Code
# 2                         10001       East     Paypal          93816545
# 3                         10002       West     Credit          74083490
# 4                         10003      North     Credit          64942368
# ..                          ...        ...        ...               ...
# 469                       10468      South     Credit          47286881
# 470                       10469      North     Paypal          62265606
# 471                       10470       West     Credit          63133211
# 472                       10471       West     Paypal          24646414
# 473                       10472      North     Credit          65043803
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6   Unnamed: 7
# ...

# %%
joan.isnull()
# Out:
#      Sales Transactions: July 14  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0                           True        True        True        True
# 1                          False       False       False       False
# 2                          False       False       False       False
# 3                          False       False       False       False
# 4                          False       False       False       False
# ..                           ...         ...         ...         ...
# 469                        False       False       False       False
# 470                        False       False       False       False
# 471                        False       False       False       False
# 472                        False       False       False       False
# 473                        False       False       False       False
#
#      Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7
# 0          True        True        True        True
# ...

# %%
joan.isnull().sum()
# Out:
# Sales Transactions: July 14    1
# Unnamed: 1                     1
# Unnamed: 2                     1
# Unnamed: 3                     1
# Unnamed: 4                     1
# Unnamed: 5                     1
# Unnamed: 6                     1
# Unnamed: 7                     1
# dtype: int64

# %%
joan.isna()
# Out:
#      Sales Transactions: July 14  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0                           True        True        True        True
# 1                          False       False       False       False
# 2                          False       False       False       False
# 3                          False       False       False       False
# 4                          False       False       False       False
# ..                           ...         ...         ...         ...
# 469                        False       False       False       False
# 470                        False       False       False       False
# 471                        False       False       False       False
# 472                        False       False       False       False
# 473                        False       False       False       False
#
#      Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7
# 0          True        True        True        True
# ...

# %% [markdown]
# tell us which ones are missing

# %%
kent.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 500    False
# 501    False
# 502    False
# 503    False
# 504    False
# Length: 505, dtype: bool

# %% [markdown]
# shows how many are deuplicated

# %% [markdown]
# hhhhhhhhhhhhh
